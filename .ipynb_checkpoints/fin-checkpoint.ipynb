# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import stats
import dill

# %%
SP = pd.read_csv('data/^GSPC.csv').dropna()
SP.tail()
# Out:
#              Date         Open         High          Low        Close  \
# 23344  2020-12-07  3694.729980  3697.409912  3678.879883  3691.959961
# 23345  2020-12-08  3683.050049  3708.449951  3678.830078  3702.250000
# 23346  2020-12-09  3705.979980  3712.389893  3660.540039  3672.820068
# 23347  2020-12-10  3659.129883  3678.489990  3645.179932  3668.100098
# 23348  2020-12-11  3656.080078  3665.909912  3633.399902  3663.459961
#
#          Adj Close      Volume
# 23344  3691.959961  4788560000
# 23345  3702.250000  4549670000
# 23346  3672.820068  5209940000
# 23347  3668.100098  4618240000
# 23348  3663.459961  4367150000

# %%
# SP.rename(columns={'GOLDAMGBD228NLBM': 'Close'}, inplace=True)
# SP.Close = SP.Close.apply(pd.to_numeric, errors='coerce')
SP.Close = SP.Close.fillna(method='ffill')

# %%
SP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23349 entries, 0 to 23348
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23349 non-null  object
#  1   Open       23349 non-null  float64
#  2   High       23349 non-null  float64
#  3   Low        23349 non-null  float64
#  4   Close      23349 non-null  float64
#  5   Adj Close  23349 non-null  float64
#  6   Volume     23349 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
SP = SP.iloc[::-1]

# %%
# chnd = (SP.Close.iloc[0]/SP.Close.iloc[0 + period_pred] - 1)*100
# chnd, SP.Close.iloc[0], SP.Close.iloc[0 + period_pred]

# %%
df = []
n_cols = 100

#с конца всего датасета
for i in range(5000):
    period_pred = 15
    chnd = (SP.Close.iloc[i]/SP.Close.iloc[i + period_pred] - 1)*100
    row = []
    if chnd > 5:
        row.append(1)
    else:
        row.append(0)
#     for j in (1, 2, 3, 4, 5, 6, 8, 10, 13, 17, 22):
    for j in range(n_cols):
        row.append(SP.Close.iloc[j + i])
    df.append(row)

# %%
df = pd.DataFrame(df)
df.columns = [str(i) for i in range(n_cols + 1)]
df.head()
# Out:
#    0            1            2            3            4            5  \
# 0  0  3663.459961  3668.100098  3672.820068  3702.250000  3691.959961
# 1  0  3668.100098  3672.820068  3702.250000  3691.959961  3699.120117
# 2  0  3672.820068  3702.250000  3691.959961  3699.120117  3666.719971
# 3  0  3702.250000  3691.959961  3699.120117  3666.719971  3669.010010
# 4  0  3691.959961  3699.120117  3666.719971  3669.010010  3662.449951
#
#              6            7            8            9  ...           91  \
# 0  3699.120117  3666.719971  3669.010010  3662.449951  ...  3327.770020
# 1  3666.719971  3669.010010  3662.449951  3621.629883  ...  3306.510010
# 2  3669.010010  3662.449951  3621.629883  3638.350098  ...  3294.610107
# 3  3662.449951  3621.629883  3638.350098  3629.649902  ...  3271.120117
# 4  3621.629883  3638.350098  3629.649902  3635.409912  ...  3246.219971
#
#             92           93           94           95           96  \
# 0  3306.510010  3294.610107  3271.120117  3246.219971  3258.439941
# 1  3294.610107  3271.120117  3246.219971  3258.439941  3218.439941
# 2  3271.120117  3246.219971  3258.439941  3218.439941  3239.409912
# 3  3246.219971  3258.439941  3218.439941  3239.409912  3215.629883
# 4  3258.439941  3218.439941  3239.409912  3215.629883  3235.659912
#
#             97           98           99          100
# 0  3218.439941  3239.409912  3215.629883  3235.659912
# 1  3239.409912  3215.629883  3235.659912  3276.020020
# 2  3215.629883  3235.659912  3276.020020  3257.300049
# 3  3235.659912  3276.020020  3257.300049  3251.840088
# 4  3276.020020  3257.300049  3251.840088  3224.729980
#
# [5 rows x 101 columns]

# %%
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score, classification_report, precision_recall_curve, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['0'], 1), df['0'], random_state=0)

# %%
# with open('rf.dill', 'wb') as in_strm:
#     in_strm.write(dill.dumps(pipeline))

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
preds = rf.predict_proba(X_test)[:, 1]

precision, recall, thresholds = precision_recall_curve(y_test, preds)

fscore = (2 * precision/50 * recall) / (precision/50 + recall)
# locate the index of the largest f score
ix = np.argmax(fscore)
print('Best Threshold=%.3f, F-Score=%.3f, Precision=%.3f, Recall=%.3f' % (thresholds[ix], 
                                                                        fscore[ix],
                                                                        precision[ix],
                                                                        recall[ix]))
# Out:
# Best Threshold=0.530, F-Score=0.037, Precision=0.974, Recall=0.378

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.9216
# 1    0.0784
# Name: 0, dtype: float64

# %%
preds = rf.predict_proba(df.drop(['0'], 1))[:, 1]
preds
# Out:
# array([0.06, 0.06, 0.01, ..., 0.07, 0.65, 0.63])

# %%
len(preds)
# Out:
# 5000

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
fig.set_size_inches(18, 5)
lns1 = ax.plot(preds[:1500])
ax2 = ax.twinx()
lns2 = ax2.plot(df['1'][:1500], linewidth=3, c='g', label='y')
lns = lns1+lns2
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.scatter(df['1'], preds, s=2)
plt.title('Диаграмма рассеяния')
plt.xlabel('S&P 500')
# plt.ylabel('казначейские облигации')
plt.show()
df['1'].corr(pd.Series(preds))
# Out:
# -0.052899269317007135
