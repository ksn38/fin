# %%
import pandas as pd
import numpy as np

# %%
SP = pd.read_csv('data/^GSPC.csv').dropna()
SP = SP[['Date', 'Close']]#[8600:]
SP.head()
# Out:
#          Date      Close
# 0  1927-12-30  17.660000
# 1  1928-01-03  17.760000
# 2  1928-01-04  17.719999
# 3  1928-01-05  17.549999
# 4  1928-01-06  17.660000

# %%
TR = pd.read_csv('data/^TNX.csv').dropna()
TR = TR[['Date', 'Close']]#[8600:]
TR.head()
# Out:
#          Date  Close
# 0  1962-01-02   4.06
# 1  1962-01-03   4.03
# 2  1962-01-04   3.99
# 3  1962-01-05   4.02
# 5  1962-01-08   4.03

# %%
VIX = pd.read_csv('data/^VIX.csv').dropna()
VIX = VIX[['Date', 'Close']]#[8600:]
VIX.head()
# Out:
#          Date      Close
# 0  1990-01-02  17.240000
# 1  1990-01-03  18.190001
# 2  1990-01-04  19.219999
# 3  1990-01-05  20.110001
# 4  1990-01-08  20.260000

# %%
# x = pd.concat([SP, VIX], axis=1)
x = pd.merge(SP, VIX, how='left', on='Date')
x = pd.merge(x, TR, how='left', on='Date')
# x.Close = x.Close.fillna(0.855)
x = x[:-1]
x
# Out:
#              Date      Close_x    Close_y  Close
# 0      1927-12-30    17.660000        NaN    NaN
# 1      1928-01-03    17.760000        NaN    NaN
# 2      1928-01-04    17.719999        NaN    NaN
# 3      1928-01-05    17.549999        NaN    NaN
# 4      1928-01-06    17.660000        NaN    NaN
# ...           ...          ...        ...    ...
# 23343  2020-12-04  3699.120117  20.790001  0.969
# 23344  2020-12-07  3691.959961  21.299999  0.928
# 23345  2020-12-08  3702.250000  20.680000  0.913
# 23346  2020-12-09  3672.820068  22.270000  0.941
# 23347  2020-12-10  3668.100098  22.520000  0.908
#
# [23348 rows x 4 columns]

# %%
x.Close = x.Close.fillna(method='ffill')
# x.Close_y = x.Close_y.fillna(method='backfill')
# x = x[8600:]
x.Date = pd.to_datetime(x.Date)
x.info()
x.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23348 entries, 0 to 23347
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     23348 non-null  datetime64[ns]
#  1   Close_x  23348 non-null  float64
#  2   Close_y  7798 non-null   float64
#  3   Close    14839 non-null  float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 912.0 KB
#          Date    Close_x  Close_y  Close
# 0  1927-12-30  17.660000      NaN    NaN
# 1  1928-01-03  17.760000      NaN    NaN
# 2  1928-01-04  17.719999      NaN    NaN
# 3  1928-01-05  17.549999      NaN    NaN
# 4  1928-01-06  17.660000      NaN    NaN
# 5  1928-01-09  17.500000      NaN    NaN
# 6  1928-01-10  17.370001      NaN    NaN
# 7  1928-01-11  17.350000      NaN    NaN
# 8  1928-01-12  17.469999      NaN    NaN
# 9  1928-01-13  17.580000      NaN    NaN
# 10 1928-01-16  17.290001      NaN    NaN
# 11 1928-01-17  17.299999      NaN    NaN
# ...

# %%
x.columns = ['date_added', 'GSPC', 'VIX', 'TNX']
x.to_csv('mybl_ticker.csv', index=False)
